# %% [markdown]
# # Дополнительное задание
#
# Нейронная сеть может быть использована для решения нескольких задач одновременно.
# Реализуйте архитектуру нейронной сети представленной на рисунке ниже.
#
# <img src="nn.png">
#
# Используйте данные Ирисов из sklearn.datasets. Нейронная сеть должна предсказывать класса ириса и ширину лепестка по трем оставшимся признакам.
# Датасет разделите случайным образом на тренировочную и валидационную подвыборки в отношении 4:1
#
# Задачи:
# 1. реализовать для внутренних нейронов функции активации и их производные в виде функций (сигмоид, гиперболический тангенс, линейный выпрямитель);
# 2. реализовать для выходных нейронов функции активации и их производные в виде функций (линейная для регрессии, софтмакс для классификации);
# 3. реализовать функции потерь и их производные (средний квадрат отклонения (MSE) для регрессии, перекрестная кроссэнтропия (CCE) для классификации);
# 4. сгенерировать веса в каждом из слоев в диапазоне $[-1, 1]$;
# 5. реализовать прямой проход по нейронной сети для каждого пути (регрессии и классификации) для получения значений на выходе нейронной;
# 6. реализовать обратные проходы по нейронной сети для каждого пути (регрессии и классификации) для получения значений изменений весов в слоях;
#
# При прямом проходе вы получаете значения выходов. Сравниваете выходы с действительными значения через функций потерь (MSE и ССЕ). Минимизируете функции потерь через производные, проходя последовательно через все слои.

# %%
import numpy as np
from sklearn.datasets import load_iris

data = load_iris()
print(data.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...
